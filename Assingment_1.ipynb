# %%
# Write a Python program to print "Hello Python&quot"?

print('Hello Python')
# Out:
# Hello Python

# %%
# 2. Write a Python program to do arithmetical operations addition and division.?

a = int(input("Enter a number: "))
b = int(input("Enter a number: "))
c = input("Enter operator: ")
if c == "+":
    print(a+b)
elif c == "/":
    print(a/b)
else:
    print("Invalid input")
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter operator: +
# 9

# %%
#3. Write a Python program to find the area of a triangle?

a =int(input("Enter height: "))
b = int(input("Enter base: "))
area = (a*b)/2
print(area)
# Out:
# Enter height: 4
# Enter base: 5
# 10.0

# %%
#4. Write a Python program to swap two variables?

a = int(input("Enter a number: "))
print("num 1 = " ,a," before swap")
b = int(input("Enter a number: "))
print( "num 2 = ",b," before swap")
c = b
b =a
print("num 2= ", b,"after Swap")
a = c
print("num 1 = ",a, "After swap")
# Out:
# Enter a number: 5
# num 1 =  5  before swap
# Enter a number: 2
# num 2 =  2  before swap
# num 2=  5 after Swap
# num 1 =  2 After swap

# %%
#5. Write a Python program to generate a random number?

import random
print(random.randint(0,55))
# Out:
# 16
